# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('./score/rnn/train_score.txt', 'r') as f:
    tr_rnn = f.read().splitlines()

tr_rnn_score = [eval(ele) for ele in tr_rnn]
tr_rnn_loss = [ele[0] for ele in tr_rnn_score]
tr_rnn_acc = [ele[1] for ele in tr_rnn_score]
tr_rnn_p1 = [ele[2] for ele in tr_rnn_score]
tr_rnn_r1 = [ele[3] for ele in tr_rnn_score]
tr_rnn_p2 = [ele[4] for ele in tr_rnn_score]
tr_rnn_r2 = [ele[5] for ele in tr_rnn_score]

# %%
with open('./score/rnn/test_score.txt', 'r') as f:
    te_rnn = f.read().splitlines()

te_rnn_score = [eval(ele) for ele in te_rnn]
te_rnn_loss = [ele[0] for ele in te_rnn_score]
te_rnn_acc = [ele[1] for ele in te_rnn_score]
te_rnn_p1 = [ele[2] for ele in te_rnn_score]
te_rnn_r1 = [ele[3] for ele in te_rnn_score]
te_rnn_p2 = [ele[4] for ele in te_rnn_score]
te_rnn_r2 = [ele[5] for ele in te_rnn_score]

# %%
plt.plot(tr_rnn_acc)
plt.plot(te_rnn_acc)
plt.show()
